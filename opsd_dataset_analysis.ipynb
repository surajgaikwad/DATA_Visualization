# %%
import pandas as pd
pd.to_datetime('2018-01-15 3:45pm')
# Out:
# Timestamp('2018-01-15 15:45:00')

# %%
pd.to_datetime('7/8/1952') #mm/dd/yyyy
# Out:
# Timestamp('1952-07-08 00:00:00')

# %%
pd.to_datetime('7/8/1952', dayfirst=True) #dd/mm/yyyy
# Out:
# Timestamp('1952-08-07 00:00:00')

# %%
pd.to_datetime(['2018-01-05', '7/8/1952' , 'Oct 10, 1995'])
# Out:
# DatetimeIndex(['2018-01-05', '1952-07-08', '1995-10-10'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2018-01-05', '7/8/1952' , 'Oct 10, 1995'], dayfirst=True)
# Out:
# DatetimeIndex(['2018-01-05', '1952-08-07', '1995-10-10'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(['2/25/10', '8/6/17', '12/15/12'], format='%m/%d/%y')
# Out:
# DatetimeIndex(['2010-02-25', '2017-08-06', '2012-12-15'], dtype='datetime64[ns]', freq=None)

# %%
opsd_daily = pd.read_csv('opsd_germany_daily.csv')
opsd_daily.shape
# Out:
# (4383, 5)

# %%
opsd_daily
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
opsd_daily.head(3)
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN

# %%
opsd_daily.tail(3)
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156

# %%
opsd_daily.dtypes
# Out:
# Date            object
# Consumption    float64
# Wind           float64
# Solar          float64
# Wind+Solar     float64
# dtype: object

# %%
opsd_daily = opsd_daily.set_index('Date')
opsd_daily
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 opsd_daily = opsd_daily.set_index('Date')
#       2 opsd_daily
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:6001, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5998                 missing.append(col)
#    6000 if missing:
# ...

# %%
opsd_daily
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
opsd_daily.index
# Out:
# Index(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04', '2006-01-05',
#        '2006-01-06', '2006-01-07', '2006-01-08', '2006-01-09', '2006-01-10',
#        ...
#        '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25', '2017-12-26',
#        '2017-12-27', '2017-12-28', '2017-12-29', '2017-12-30', '2017-12-31'],
#       dtype='object', name='Date', length=4383)

# %%
opsd_daily = pd.read_csv('opsd_germany_daily.csv', index_col=0, parse_dates=True) # all above steps in one line code
opsd_daily
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %%
# Add columns with year, month, and weekday name
opsd_daily['Year'] = opsd_daily.index.year
opsd_daily['Month'] = opsd_daily.index.month                     # for month name - opsd_daily.index.month_name()
opsd_daily['Weekday Name'] = opsd_daily.index.day_name()         # notice the () just for day_name method 
# Display a random sampling of 5 rows
opsd_daily.tail(5)
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12    Wednesday
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12     Thursday
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12       Friday
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12     Saturday
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12       Sunday

# %% [markdown]
# ### Time-based indexing

# %% [markdown]
# #### using dates and times to intuitively organize and access our data

# %%
opsd_daily.loc['2017-08-10']
# Out:
# Consumption     1351.491
# Wind             100.274
# Solar              71.16
# Wind+Solar       171.434
# Year                2017
# Month                  8
# Weekday Name    Thursday
# Name: 2017-08-10 00:00:00, dtype: object

# %%
opsd_daily.loc['2014-01-20':'2014-01-22']     # inclusive of both dates
# Out:
#             Consumption    Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2014-01-20     1590.687  78.647   6.371      85.018  2014      1       Monday
# 2014-01-21     1624.806  15.643   5.835      21.478  2014      1      Tuesday
# 2014-01-22     1625.155  60.259  11.992      72.251  2014      1    Wednesday

# %% [markdown]
# #### partial-string indexing

# %%
opsd_daily.loc['2014-01'] # selects entire year-month string
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2014-01-01     1080.080  220.085  30.493     250.578  2014      1    Wednesday
# 2014-01-02     1343.101  304.166  13.680     317.846  2014      1     Thursday
# 2014-01-03     1379.776  340.639  23.510     364.149  2014      1       Friday
# 2014-01-04     1271.029  260.828  15.227     276.055  2014      1     Saturday
# 2014-01-05     1182.416  175.812  18.067     193.879  2014      1       Sunday
# 2014-01-06     1408.202  370.910  26.281     397.191  2014      1       Monday
# 2014-01-07     1529.250  363.756  44.463     408.219  2014      1      Tuesday
# 2014-01-08     1550.398  287.099  35.228     322.327  2014      1    Wednesday
# 2014-01-09     1572.194  430.360  23.977     454.337  2014      1     Thursday
# 2014-01-10     1552.413  376.860  30.979     407.839  2014      1       Friday
# 2014-01-11     1350.439  308.404  23.923     332.327  2014      1     Saturday
# ...

# %% [markdown]
# ## Visualizing time series data

# %%
import matplotlib.pyplot as plt
# Display figures inline in Jupyter notebook

# %%
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
opsd_daily['Consumption'].plot(linewidth=0.5)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
col_plots = [ 'Consumption', 'Solar', 'Wind']
#axes = opsd_daily[col_plots].plot(linewidth=0.5, subplots=True)
axes = opsd_daily[col_plots].plot(linewidth=0.5, subplots=True)

# %%
cols_plots = ['Consumption', 'Solar', 'Wind']
axes = opsd_daily[cols_plots].plot(marker='.', alpha=0.3, linestyle=None , figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily Totals (GWh)')

# %% [markdown]
# #### marker , https://matplotlib.org/stable/api/markers_api.html

# %%
# with star(*) marker https://matplotlib.org/stable/api/markers_api.html
cols_plots = ['Consumption', 'Solar', 'Wind']
axes = opsd_daily[cols_plots].plot(marker='*', alpha=0.3, linestyle=None , figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Daily Totals (GWh)')

# %%
ax = opsd_daily.loc['2017', 'Consumption'].plot(linewidth=0.5)
ax.set_ylabel("Daily Consumption (GWh)")
# Out:
# Text(0, 0.5, 'Daily Consumption (GWh)')

# %%
ax = opsd_daily.loc['2017-01':'2017-02', 'Consumption'].plot(marker='o', linestyle='-')
ax.set_ylabel("Daily Consumption (GWh)")
# Out:
# Text(0, 0.5, 'Daily Consumption (GWh)')

# %% [markdown]
# ### Customizing time series plots

# %%
import matplotlib.dates as mdates

fig, ax = plt.subplots()
ax.plot(opsd_daily.loc['2017-01':'2017-02', 'Consumption'], marker='o', linestyle='--')
ax.set_ylabel("Daily Consumption GWh")
ax.set_title("Jan-Feb Electricity COnsumption")

# Ste x-axis major ticks to weekly interval, on monday (vertial white line on Monday)
ax.xaxis.set_major_locator(mdates.WeekdayLocator(byweekday=mdates.MONDAY))

# Format x-ticks labels as 3 letter month name and day number
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# %% [markdown]
# ### Seasonality
